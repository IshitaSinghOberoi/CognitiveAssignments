# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(102317272)

sales_data = np.random.randint(1000, 5001, size=(12, 4))

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
columns = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
df = pd.DataFrame(sales_data, columns=columns, index=months)
print(df)

print("First 5 rows:\n", df.head())
print("\nSummary Statistics:\n", df.describe())

totalSalesCategory = df.sum()
print("\nTotal Sales per Category:\n", totalSalesCategory)
totalsalespermonth = df.sum(axis=1)
print("\nTotal Sales per Month:\n", totalsalespermonth)

df["Total Sales"] = df.sum(axis=1)
df["Growth Rate"] = df["Total Sales"].pct_change() * 100

roll_number = 102317172
if roll_number % 2 == 0:

    df['Electronics Discounted'] = df['Electronics'] * 0.90
else:

    df['Clothing Discounted'] = df['Clothing'] * 0.85
df.head()


plt.figure(figsize=(10, 6))
for column in df.columns[:-2]:
    plt.plot(df.index, df[column], label=column)

plt.title('Monthly Sales Trends for Each Category')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(data=df.drop(columns=['Total Sales', 'Growth Rate']), orient='v')
plt.title('Sales Distribution by Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1450      1739            4208    2698
# Feb         4970      1117            3501    4619
# Mar         2768      1632            2641    2850
# Apr         4624      2061            2471    1193
# May         3075      3930            3687    4294
# Jun         3978      3791            1320    1097
# Jul         2768      3821            3838    4356
# Aug         3518      1799            1358    2222
# Sep         4491      3267            1862    3192
# Oct         1951      1018            3471    2296
# Nov         2353      1983            3243    4296
# Dec         1484      2955            4058    4869
# First 5 rows:
#       Electronics  Clothing  Home & Kitchen  Sports
# Jan         1450      1739            4208    2698
# Feb         4970      1117            3501    4619
# Mar         2768      1632            2641    2850
# Apr         4624      2061            2471    1193
# May         3075      3930            3687    4294
#
# Summary Statistics:
#         Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3119.166667  2426.083333     2971.500000  3165.166667
# std    1210.889818  1069.381338     1022.355347  1318.327993
# min    1450.000000  1018.000000     1320.000000  1097.000000
# 25%    2252.500000  1712.250000     2318.750000  2277.500000
# 50%    2921.500000  2022.000000     3357.000000  3021.000000
# 75%    4106.250000  3398.000000     3724.750000  4311.000000
# max    4970.000000  3930.000000     4208.000000  4869.000000
#
# Total Sales per Category:
#  Electronics       37430
# Clothing          29113
# Home & Kitchen    35658
# Sports            37982
# dtype: int64
#
# Total Sales per Month:
#  Jan    10095
# Feb    14207
# Mar     9891
# Apr    10349
# May    14986
# Jun    10186
# Jul    14783
# Aug     8897
# Sep    12812
# Oct     8736
# Nov    11875
# Dec    13366
# dtype: int64

# %%
import numpy as np
array = np.array([[1, -2, 3], [-4, 5, -6]])
abs_array = np.abs(array)
print("Element-wise absolute value:",abs_array)

flattened_array = array.flatten()

percentiles_flattened = np.percentile(flattened_array, [25, 50, 75])
print("\nPercentiles (25th, 50th, 75th) for flattened array:")
print(f"25th: {percentiles_flattened[0]}, 50th: {percentiles_flattened[1]}, 75th: {percentiles_flattened[2]}")

percentiles_columns = np.percentile(array, [25, 50, 75], axis=0)
print("\nPercentiles (25th, 50th, 75th) for each column:")
print(f"25th: {percentiles_columns[0]}")
print(f"50th: {percentiles_columns[1]}")
print(f"75th: {percentiles_columns[2]}")

percentiles_rows = np.percentile(array, [25, 50, 75], axis=1)
print("\nPercentiles (25th, 50th, 75th) for each row:")
print(f"25th: {percentiles_rows[0]}")
print(f"50th: {percentiles_rows[1]}")
print(f"75th: {percentiles_rows[2]}")

mean_flattened = np.mean(flattened_array)
median_flattened = np.median(flattened_array)
std_flattened = np.std(flattened_array)

print("\nMean, Median, and Standard Deviation for flattened array:")
print(f"Mean: {mean_flattened}, Median: {median_flattened}, Std Dev: {std_flattened}")

mean_columns = np.mean(array, axis=0)
median_columns = np.median(array, axis=0)
std_columns = np.std(array, axis=0)

print("\nMean, Median, and Standard Deviation for each column:")
print(f"Mean: {mean_columns}")
print(f"Median: {median_columns}")
print(f"Std Dev: {std_columns}")

mean_rows = np.mean(array, axis=1)
median_rows = np.median(array, axis=1)
std_rows = np.std(array, axis=1)

print("\nMean, Median, and Standard Deviation for each row:")
print(f"Mean: {mean_rows}")
print(f"Median: {median_rows}")
print(f"Std Dev: {std_rows}")
# Out:
# Element-wise absolute value: [[1 2 3]
#  [4 5 6]]
#
# Percentiles (25th, 50th, 75th) for flattened array:
# 25th: -3.5, 50th: -0.5, 75th: 2.5
#
# Percentiles (25th, 50th, 75th) for each column:
# 25th: [-2.75 -0.25 -3.75]
# 50th: [-1.5  1.5 -1.5]
# 75th: [-0.25  3.25  0.75]
#
# Percentiles (25th, 50th, 75th) for each row:
# 25th: [-0.5 -5. ]
# 50th: [ 1. -4.]
# 75th: [2.  0.5]
#
# Mean, Median, and Standard Deviation for flattened array:
# Mean: -0.5, Median: -0.5, Std Dev: 3.8622100754188224
#
# Mean, Median, and Standard Deviation for each column:
# Mean: [-1.5  1.5 -1.5]
# Median: [-1.5  1.5 -1.5]
# Std Dev: [2.5 3.5 4.5]
#
# Mean, Median, and Standard Deviation for each row:
# Mean: [ 0.66666667 -1.66666667]
# Median: [ 1. -4.]
# Std Dev: [2.05480467 4.78423336]

# %%
import numpy as np
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print("Original Array:", a)
floor_values = np.floor(a)
print("Floor Values:", floor_values)
ceiling_values = np.ceil(a)
print("Ceiling Values:", ceiling_values)
truncated_values = np.trunc(a)
print("Truncated Values:", truncated_values)
rounded_values = np.round(a)
print("Rounded Values:", rounded_values)
# Out:
# Original Array: [-1.8 -1.6 -0.5  0.5  1.6  1.8  3. ]
# Floor Values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling Values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated Values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded Values: [-2. -2. -0.  0.  2.  2.  3.]

# %%
l = [1, 2, 3, 4, 5]
print("List before swapping:", l)
temp = l[1]
l[1] = l[3]
l[3] = temp
print("List after swapping:", l)
# Out:
# List before swapping: [1, 2, 3, 4, 5]
# List after swapping: [1, 4, 3, 2, 5]

# %%
s = {10, 20, 30, 40, 50}
print("Set before swapping:", s)
s_list = list(s)
s_list[1], s_list[3] = s_list[3], s_list[1]
s = set(s_list)
print("Set after swapping:", s)
# Out:
# Set before swapping: {50, 20, 40, 10, 30}
# Set after swapping: {40, 10, 50, 20, 30}
